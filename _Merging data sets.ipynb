# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
EP6_docs = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP6_docs.csv")
#EP7_docs = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP7_docs.csv")
#EP8_docs = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP8_docs.csv")

# %%
EP6_scraped1 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP6scraped_1.csv")
EP6_scraped2 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP6scraped_2.csv")
EP6_scraped3 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP6scraped_3.csv")
EP6_scraped4 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP6scraped_4.csv")
EP6_scraped5 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP6scraped_5.csv")
EP6_scraped6 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP6scraped_6.csv")

# %%
"""EP8_scraped1 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP8scraped_1.csv")
EP8_scraped2 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP8scraped_2.csv")
EP8_scraped3 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP8scraped_3.csv")
EP8_scraped4 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP8scraped_4.csv")
EP8_scraped5 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP8scraped_5.csv")
EP8_scraped7 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP8scraped_7.csv")
EP8_scraped8 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP8scraped_8.csv")
EP8_scraped9 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP8scraped_9.csv")
EP8_scraped10 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP8scraped_10.csv")"""

# %%
EP8_scraped6 = pd.read_csv("/content/drive/MyDrive/ Thesis 2023/EP8scraped_6.csv")

# %%
EP6_complete = pd.concat([EP6_scraped1, EP6_scraped2, EP6_scraped3,EP6_scraped4,EP6_scraped5,EP6_scraped6], ignore_index=True)

# %%
EP6_complete.isna().sum()
# Out:
# Unnamed: 0       0
# link             0
# raw_text      2123
# title            0
# dtype: int64

# %%
EP6_docs.isna().sum()
# Out:
# Unnamed: 0             0
# euro_act_id            0
# date                   0
# title                  0
# procedure           3121
# reading                0
# type_of_vote          83
# type_of_vote_en       83
# rule                  66
# raporteur             92
# url                    8
# committee_code       440
# main_policy_name       0
# subject              906
# final_vote             0
# author_name         1207
# am_no               1660
# result_code            8
# yes                    0
# no                     3
# abstain                3
# did_not_vote           0
# absent                 0
# absent_motivated       0
# dtype: int64

# %%
EP6_docs.head()
# Out:
#    Unnamed: 0  euro_act_id                 date  \
# 0           0            1  2004-09-15 00:00:00
# 1           1            2  2004-09-15 00:00:00
# 2           2            3  2004-09-15 00:00:00
# 3           3            4  2004-09-15 00:00:00
# 4           4            5  2004-09-15 00:00:00
#
#                              title procedure reading  \
# 0   EU-Mauritius fishing agreement     CNS *     Leg
# 1   EU-Mauritius fishing agreement     CNS *     Leg
# 2  EU-Madagascar Fishing agreement     CNS *     Leg
# 3  EU-Madagascar Fishing agreement     CNS *     Leg
# 4  EU-Cape Verde Fishing agreement     CNS *     Leg
#
#                                       type_of_vote  \
# 0        Amended proposal for a Council regulation
# 1  Legislative resolution for a Council regulation
# 2        Amended proposal for a Council regulation
# 3  Legislative resolution for a Council regulation
# 4        Amended proposal for a Council regulation
#
# ...

# %%
EP6_docs.drop(["raporteur","type_of_vote_en","rule" ], axis= "columns", inplace=True)

# %%
EP6_docs.shape
# Out:
# (6199, 21)

# %%
# Get the list of column names
columns = EP6_docs.columns.tolist()

# Print the list of columns
print(columns)
# Out:
# ['Unnamed: 0', 'euro_act_id', 'date', 'title', 'procedure', 'reading', 'type_of_vote', 'url', 'committee_code', 'main_policy_name', 'subject', 'final_vote', 'author_name', 'am_no', 'result_code', 'yes', 'no', 'abstain', 'did_not_vote', 'absent', 'absent_motivated']

# %%
EP6_complete['Vote ID'] = range(1, len(EP6_complete) + 1)

# %%
EP_6th = EP6_docs.merge( EP6_complete, how = "inner", left_on = "euro_act_id", right_on= "Vote ID")

# %%
EP_6th.shape
# Out:
# (6199, 26)

# %%
EP8_complete = pd.concat([EP8_scraped1, EP8_scraped2, EP8_scraped3,EP8_scraped4,EP8_scraped5,EP8_scraped6,EP8_scraped7,EP8_scraped8,EP8_scraped9,EP8_scraped10], ignore_index=True)
EP8_complete.shape
# Out:
# (10243, 3)

# %%
print(EP7_docs['Link'].duplicated().sum()) # should be 0
print(EP7_complete['link'].duplicated().sum()) # should be 0
# Out:
# 5077
# 5068

# %%
print(len(EP7_docs['Link'].unique())) # should be 6000
print(len(EP7_complete['link'].unique())) # should be 6000
# Out:
# 1884
# 1884

# %%
EP7_complete['Vote ID'] = range(1, len(EP7_complete) + 1)

# %%
print(EP7_docs['Vote ID'].duplicated().sum()) # should be 0
print(EP7_complete['Vote ID'].duplicated().sum()) # should be 0
# Out:
# 0
# 0

# %%
EP_7th = EP7_docs.merge( EP7_complete, how = "inner", left_on = "Vote ID", right_on= "Vote ID")

# %%
EP_7th.shape
# Out:
# (6950, 22)

# %%
EP_7th.head()
# Out:
#    Unnamed: 0_x  Vote ID        Date  \
# 0             0        1  14.09.2009
# 1             1        2  15.09.2009
# 2             2        3  15.09.2009
# 3             3        4  15.09.2009
# 4             4        5  15.09.2009
#
#                                                Title Leg/Non-Leg/Bud  \
# 0  Election of the President of the European Comm...             Non
# 1  Agreement EC/Mongolia on certain aspects of ai...             Leg
# 2  EC-China agreement: maritime transport operati...             Leg
# 3  Mobilisation of the European Globalisation Adj...             Bud
# 4  Mobilisation of the European Union Solidarity ...             Bud
#
#                Type of Vote Voting Rule  \
# 0            Agenda setting           s
# 1    Legislative resolution           s
# 2    Legislative resolution           s
# 3  Motions for a resolution           q
# 4  Motions for a resolution           q
#
#                                                 Link  \
# ...

# %%
print(EP7_complete['raw_text'].duplicated().sum()) 
print(len(EP7_complete['raw_text'].unique())) 
print(EP_7th['raw_text'].duplicated().sum())
print(len(EP_7th['raw_text'].unique())) 
print(EP_7th['Vote ID'].duplicated().sum())
print(len(EP_7th['Vote ID'].unique()))
# Out:
# 5140
# 1812
# 5138
# 1812
# 0
# 6950

# %%
path = '/content/drive/MyDrive/ Thesis 2023/EP7_final.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 EP_7th.to_csv(f)

# %%
path = '/content/drive/MyDrive/ Thesis 2023/EP6_final.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 EP_6th.to_csv(f)

# %% [markdown]
# # EP 8

# %%
EP8_docs.drop(["Order of vote","File","O'clock","Procedure","Rapporteur","Code","interinstitutional file number" ], axis= "columns", inplace=True)

# %%
EP8_docs.shape
# Out:
# (10252, 27)

# %%
EP8_complete = pd.concat([EP8_scraped1, EP8_scraped2, EP8_scraped3,EP8_scraped4,EP8_scraped5,EP8_scraped6,EP8_scraped7,EP8_scraped8,EP8_scraped9,EP8_scraped10], ignore_index=True)
EP8_complete.shape
# Out:
# (10243, 3)

# %%
print(EP8_docs['Link'].duplicated().sum()) # should be 0
print(EP8_complete['link'].duplicated().sum()) # should be 0
# Out:
# 7968
# 8143

# %%
print(len(EP8_docs['Link'].unique())) # should be 6000
print(len(EP8_complete['link'].unique())) # should be 6000
# Out:
# 2284
# 2100

# %%
EP8_complete['Vote ID'] = range(1, len(EP8_complete) + 1)

# %%
print(EP8_docs['Vote ID'].duplicated().sum()) # should be 0
print(EP8_complete['Vote ID'].duplicated().sum()) # should be 0
# Out:
# 0
# 0

# %%
EP_8th = EP8_docs.merge( EP8_complete, how = "inner", left_on = "Vote ID", right_on= "Vote ID")

# %%
EP_8th.shape
# Out:
# (10219, 30)

# %%
print(EP8_complete['raw_text'].duplicated().sum()) 
print(len(EP8_complete['raw_text'].unique())) 
print(EP_8th['raw_text'].duplicated().sum())
print(len(EP_8th['raw_text'].unique())) 
print(EP_8th['Vote ID'].duplicated().sum())
print(len(EP_8th['Vote ID'].unique()))
# Out:
# 8267
# 1976
# 8243
# 1976
# 0
# 10219

# %%
path = '/content/drive/MyDrive/ Thesis 2023/EP8_final.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 EP_8th.to_csv(f)

# %%
dummy = EP_8th.iloc[7001:8000]

# %%
path = '/content/drive/MyDrive/ Thesis 2023/dummy.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 dummy.to_csv(f)

# %%
EP8_docs['Link'].isin(EP8_complete['link']).value_counts()
# Out:
# True     9336
# False     916
# Name: Link, dtype: int64

# %%
EP7_docs['Link'].isin(EP7_complete['link']).value_counts()
# Out:
# True    6961
# Name: Link, dtype: int64
