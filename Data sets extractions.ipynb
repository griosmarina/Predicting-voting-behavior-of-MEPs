# %% [markdown]
# # Extracting the data sets

# %%
# !git clone https://github.com/griosmarina/European-data-set.git
# Out:
# Cloning into 'European-data-set'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 21 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (21/21), 248.42 MiB | 13.61 MiB/s, done.

# %%
# !unrar x /content/European-data-set/EurLex_all.part01.rar
#!unrar x /content/European-data-set/VoteWatch-EP-voting-data_2004-2022.part1.rar
#!unzip /content/European-data-set/RCV_EP_TWITTER_ACT.zip
# Out:
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from /content/European-data-set/EurLex_all.part01.rar
#
#  12%
#
# Extracting from /content/European-data-set/EurLex_all.part02.rar
#
#  24%
#
# Extracting from /content/European-data-set/EurLex_all.part03.rar
#
#  36%
#
# Extracting from /content/European-data-set/EurLex_all.part04.rar
#
#  48%
#
# Extracting from /content/European-data-set/EurLex_all.part05.rar
#
#  60%
#
# Extracting from /content/European-data-set/EurLex_all.part06.rar
#
#  72%
#
# Extracting from /content/European-data-set/EurLex_all.part07.rar
#
#  84%
#
# Extracting from /content/European-data-set/EurLex_all.part08.rar
#
#  96%
#
# Extracting from /content/European-data-set/EurLex_all.part09.rar
#
#   OK
# All OK
#
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from /content/European-data-set/VoteWatch-EP-voting-data_2004-2022.part1.rar
#
# ...

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

eurlex = pd.read_csv("/content/EurLex_all.csv")#, nrows=1000, skiprows=0)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (11,13,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
eurlex.head()
# Out:
#         CELEX                                           Act_name  Act_type  \
# 0  32019D0276  Decision (EU) 2019/276 of the European Parliam...  Decision
# 1  32019D0277  Decision (EU) 2019/277 of the European Parliam...  Decision
# 2  32019D0275  Decision (EU) 2019/275 of the European Parliam...  Decision
# 3  32018D1859  Decision (EU) 2018/1859 of the European Parlia...  Decision
# 4  32018D1720  Decision (EU) 2018/1720 of the European Parlia...  Decision
#
#      Status                                            EUROVOC  \
# 0  In Force  aid to refugees; budget appropriation; EC gene...
# 1  In Force  aid to catastrophe victims; emergency aid; EC ...
# 2  In Force  professional reintegration; Attica; EGF; EC ge...
# 3  In Force  commitment appropriation; Latvia; payment appr...
# 4  In Force  Northern Portugal; Portugal; employment aid; e...
#
#                                       Subject_matter Treaty  \
# 0  cooperation policy;  budget;  EU finance;  int...   TFEU
# ...

# %%
#action_info = pd.read_csv("/content/action_info.csv")
#mep_info = pd.read_json("/content/mep_info.json")
#mep_rcv_vote = pd.read_csv("/content/mep_rcv_vote.csv")
#rcv_info = pd.read_json("/content/rcv_info.json")

# %%
#action_info.head()

# %%
#mep_info.head()

# %%
#mep_rcv_vote.head()

# %%
#rcv_info.head(35)

# %%
EP6_RCVs = pd.read_excel("/content/VoteWatch-EP-voting-data_2004-2022 (2)/EP6_RCVs_2022_06_13.xlsx", skiprows=[0,2])

# %%
EP6_docs = pd.read_excel("/content/VoteWatch-EP-voting-data_2004-2022 (2)/EP6_Voted docs.xlsx")

# %%
EP7_RCVs = pd.read_excel("/content/VoteWatch-EP-voting-data_2004-2022 (2)/EP7_RCVs_2014_06_19.xlsx")
EP7_docs = pd.read_excel("/content/VoteWatch-EP-voting-data_2004-2022 (2)/EP7_Voted docs.xlsx")

# %%
EP8_RCVs = pd.read_excel("/content/VoteWatch-EP-voting-data_2004-2022 (2)/EP8_RCVs_2019_06_25.xlsx")
EP8_docs = pd.read_excel("/content/VoteWatch-EP-voting-data_2004-2022 (2)/EP8_Voted docs.xlsx")

# %%
EP8_RCVs.head()
# Out:
#    WebisteEpID        Fname       Lname Activ         Country  \
# 0       124990         Lars  ADAKTUSSON    no          Sweden
# 1       124831     Isabella    ADINOLFI   yes           Italy
# 2       124797        Marco    AFFRONTE   yes           Italy
# 3       124811        Laura        AGEA   yes           Italy
# 4        96897  John Stuart       AGNEW   yes  United Kingdom
#
#                                Party  \
# 0                  Kristdemokraterna
# 1                 Movimento 5 Stelle
# 2                        Independent
# 3                 Movimento 5 Stelle
# 4  United Kingdom Independence Party
#
#                                             EPG      Start        End  1  ...  \
# 0                                           NaN 2014-07-01 2018-09-23  5  ...
# 1  Europe of Freedom and Direct Democracy Group 2014-07-01 2019-12-31  5  ...
# 2    Group of the Greens/European Free Alliance 2014-07-01 2019-12-31  2  ...
# ...

# %%
EP8_docs.head(20)
# Out:
#     Vote ID  File  Order of vote                 Date  O'clock  \
# 0         1   1.0            1.0  2014-07-16 00:00:00      NaN
# 1         2   1.0            1.0  2014-07-16 00:00:00      NaN
# 2         3   1.0            2.0  2014-07-16 00:00:00      NaN
# 3         4   1.0            3.0  2014-07-16 00:00:00      NaN
# 4         5   1.0            4.0  2014-07-16 00:00:00      NaN
# 5         6   2.0            1.0  2014-07-17 00:00:00      NaN
# 6         7   2.0            2.0  2014-07-17 00:00:00      NaN
# 7         8   2.0            1.0  2014-07-17 00:00:00      NaN
# 8         9   2.0            2.0  2014-07-17 00:00:00      NaN
# 9        10   2.0            3.0  2014-07-17 00:00:00      NaN
# 10       11   2.0            4.0  2014-07-17 00:00:00      NaN
# 11       12   2.0            5.0  2014-07-17 00:00:00      NaN
# 12       13   2.0            6.0  2014-07-17 00:00:00      NaN
# 13       14   2.0            7.0  2014-07-17 00:00:00      NaN
# ...

# %%
EP9_RCVs = pd.read_excel("/content/VoteWatch-EP-voting-data_2004-2022 (2)/EP9_RCVs_2022_06_22.xlsx")
EP9_docs = pd.read_excel("/content/VoteWatch-EP-voting-data_2004-2022 (2)/EP9_Voted docs.xlsx")
# Out:
# /usr/local/lib/python3.8/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
EP9_docs.head()
# Out:
#    Vote ID  File  Order of vote        Date  \
# 0        1     1              1  15.07.2019
# 1        2     2              1  18.07.2019
# 2        3     2              2  18.07.2019
# 3        4     2              3  18.07.2019
# 4        5     2              4  18.07.2019
#
#                                     Title Procedure Leg/Non-Leg/Bud  \
# 0  Tuesday - request by the GUE/NGL group       NaN             Non
# 1     Situation at the USA-Mexican border       NaN             Non
# 2     Situation at the USA-Mexican border       NaN             Non
# 3     Situation at the USA-Mexican border       NaN             Non
# 4     Situation at the USA-Mexican border       NaN             Non
#
#                     Type of Vote Voting Rule Rapporteur  ...  \
# 0        Proposal for a decision           s          0  ...
# 1  Joint motion for a resolution           s          0  ...
# 2  Joint motion for a resolution           s          0  ...
# ...

# %% [markdown]
# # Compare the content between Eurlex procedure_number and EP8_docs interinstitutional file number, to see if they can match

# %%
print(list(EP8_docs.columns))
print(list(eurlex.columns))
# Out:
# ['Vote ID', 'File', 'Order of vote', 'Date', "O'clock", 'Title', 'Title_Ro', 'Title_Fr', 'Title_German', 'Title_Polski', 'Procedure', 'Leg/Non-Leg/Bud', 'Type of Vote', 'Voting Rule', 'Rapporteur', 'Code', 'interinstitutional file number', 'Link', 'Committee responsabile', 'De/Policy area', 'Subject', 'Subject_ro', 'Subject_fr', 'Subject_ger', 'Subject_pl', 'Final \nvote?', 'Am No.', 'Author', 'RCV', 'Vote', 'Yeas', 'No', 'Abs']
# ['CELEX', 'Act_name', 'Act_type', 'Status', 'EUROVOC', 'Subject_matter', 'Treaty', 'Legal_basis_celex', 'Authors', 'Procedure_number', 'Date_document', 'Date_publication', 'First_entry_into_force', 'Temporal_status', 'Act_cites', 'Cites_links', 'Act_ammends', 'Ammends_links', 'Eurlex_link', 'ELI_link', 'Proposal_link', 'Oeil_link', 'Additional_info', 'act_raw_text']

# %%
EP8_docs['interinstitutional file number'].isin(eurlex['Procedure_number']).value_counts()
# Out:
# False    8806
# True     1446
# Name: interinstitutional file number, dtype: int64

# %%
EP8_docs['Procedure'].isin(eurlex['Procedure_number']).value_counts()
# Out:
# True     7846
# False    2406
# Name: Procedure, dtype: int64

# %%
EP7_docs['interinstitutional file number'].isin(eurlex['Procedure_number']).value_counts()
# Out:
# False    5334
# True     1627
# Name: interinstitutional file number, dtype: int64

# %%
EP7_docs['Procedure'].isin(eurlex['Procedure_number']).value_counts()
# Out:
# True     4864
# False    2097
# Name: Procedure, dtype: int64

# %% [markdown]
# # Extract the date and year from Eurlex to keep only 2004-2019

# %%
import pandas as pd
import numpy as np
import datetime
eurlex['year'] = pd.DatetimeIndex(eurlex['Date_document']).year
eurlex['year'].unique()
# Out:
# array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        2000., 1999., 2019., 1995., 1994., 1993., 1992., 1991., 1988.,
#        1990., 1998., 1987., 1997., 1996., 1982., 1983., 1986., 1981.,
#        1985., 1989., 1975., 1962., 1978., 1980., 1976., 1984., 1966.,
#        1977., 1974., 1958., 1957., 1960., 1963., 1956., 1955., 1959.,
#        1952., 1953., 1967., 1964., 1954., 1979., 1973., 1972., 1971.,
#        1970., 1969., 1968., 1965.,   nan, 1961.])

# %%
eurlex_final = eurlex[eurlex["year"]>=2004]

# %%
print(eurlex_final.shape)
print(eurlex.shape)
# rows, columns
# Out:
# (36336, 25)
# (142036, 25)

# %%
print(EP6_docs.shape)
print(EP7_docs.shape)
print(EP8_docs.shape)
# Out:
# (6199, 23)
# (6961, 28)
# (10252, 33)

# %%
EP8_docs['Procedure'].isin(eurlex_final['Procedure_number']).value_counts()
# Out:
# True     7846
# False    2406
# Name: Procedure, dtype: int64

# %%
eurlex_final['Procedure_number'].isin(EP8_docs['Procedure']).value_counts()
# Out:
# True     30918
# False     5418
# Name: Procedure_number, dtype: int64

# %%
eurlex_final['Procedure_number'].isin(EP8_docs['interinstitutional file number']).value_counts()
# Out:
# False    35734
# True       602
# Name: Procedure_number, dtype: int64

# %% [markdown]
# ## Saving the data sets that will be used in my Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Data sets Thesis/eurlex_final.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  eurlex_final.to_csv(f)

 #ruta del archivo: "/content/drive/MyDrive/Data sets Thesis/eurlex_final.csv"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Data sets Thesis/EP6_docs.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 EP6_docs.to_csv(f)

# %%
path = '/content/drive/MyDrive/Data sets Thesis/EP6_RCVs.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 EP6_RCVs.to_csv(f)

# %%
path = '/content/drive/MyDrive/Data sets Thesis/EP7_docs.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 EP7_docs.to_csv(f)

 path = '/content/drive/MyDrive/Data sets Thesis/EP7_RCVs.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 EP7_RCVs.to_csv(f)

# %%
path = '/content/drive/MyDrive/Data sets Thesis/EP8_docs.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 EP8_docs.to_csv(f)

 path = '/content/drive/MyDrive/Data sets Thesis/EP8_RCVs.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 EP8_RCVs.to_csv(f)

# %%
path = '/content/drive/MyDrive/Data sets Thesis/EP9_docs.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 EP9_docs.to_csv(f)

 path = '/content/drive/MyDrive/Data sets Thesis/EP9_RCVs.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
 EP9_RCVs.to_csv(f)
